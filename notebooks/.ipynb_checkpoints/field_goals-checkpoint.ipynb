# %% [markdown]
# # Field Goals

# %% [markdown]
# In 2013, in the paper Going For Three, the authors undertook predictive modelling of field goal success in the NFL from 2000 to 2011. The study found that several psychological factors had little to no effect on the likelihood of field goal conversion. In 2018, in the paper Choking Under the Pressure, the authors extended the aforementioned study to include data post-2011, up to and including 2017. They found that some of the psychological factors were in fact significant at the 0.1 level.
#
# Neither study looked into the possibility of interactions between the supposedly (independent) variables, which may dilute the observed main effects. For example, one may reasonably expect that the effect of wind on a kick would increase with distance.
#
# Both studies took a frequentist statistical approach, which although provide frequency guarantees with regards to confidence intervals etc, accept and reject significance of variables at arbitrarly decided values of 0.05 and 0.1. Within Bayesian statistics, by framing parameters as random variables, we are able to give likelihoods of each variable being within some range (credible interval). Arguably more intuitive than the frequentist confidence interval. For small sample sizes, we do forgo some of the frequentist guarantees of confidence intervals, but these concerns disappear for larger samples as the two methods converge asymptotically.
#
# This notebook will include exploring the data, validating the results of the earlier papers, and exploring the possibility of interactions. With the most influential interactions, we will use a frequentist approach to the pre-2011 data, and see how our results differ from Going For Three. In the next notebook, we will incorporate these results into the prior distributions for the independent variables and train a model on post-2011 data using MCMC.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import glm as glm_sm
import numpy as np
import mysql.connector
import itertools
import dtale
from scipy.stats import chi2, pointbiserialr, pearsonr
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt


import sys
sys.path.append('..')
from util.metrics import tetrachoric
from util.graphics.factorplots import interaction_plot

# %% [markdown]
# ## Load Data

# %% [markdown]
# Set up a connection to the mysql database served locally.

# %%
cnx = mysql.connector.connect(user='root', password='mOntie20!mysql', host='127.0.0.1', database='nfl')

# %% [markdown]
# Our select clause doesn't change between models so we'll keep it here.

# %%
base_query = '''select
p.pid,fg.good,fg.dist, 
g.seas as year, k.seas as seasons,
case when g.temp<50 then 1 else 0 end as cold,
case when g.stad like "%Mile High%" then 1 else 0 end as altitude,
case when g.humd>=60 then 1 else 0 end as humid,
case when g.wspd>=10 then 1 else 0 end as windy,
case when g.v=p.off then 1 else 0 end as away_game,
case when g.wk>=10 then 1 else 0 end as postseason,
case when (pp.qtr=p.qtr) and ((pp.timd-p.timd)>0 or (pp.timo-p.timo)>0) then 1 else 0 end as iced,
case g.surf when 'Grass' then 0 else 1 end as turf,
case when g.cond like "%Snow%" then 1 when g.cond like "%Rain%" and not "Chance Rain" then 1 else 0 end as precipitation,
case when p.qtr=4 and ABS(p.ptso - p.ptsd)>21 then 0
when p.qtr=4 and p.min<2 and ABS(p.ptso - p.ptsd)>8 then 0
when p.qtr=4 and p.min<2 and p.ptso-p.ptsd < -7 then 0
when p.qtr<=3 then 0
when p.qtr=4 and p.min>=2 and ABS(p.ptso - p.ptsd)<21 then 0
when p.qtr=4 and p.min<2 and p.ptso-p.ptsd >=5 and p.ptso-p.ptsd <=8 then 0
when p.qtr=4 and p.min<2 and p.ptso-p.ptsd >=-4 and p.ptso-p.ptsd <=-6 then 0
else 1 end as pressure'''

# %% [markdown]
# We shall first load all the data and inspect it with the d-tale tool or similar pandas functions.

# %%
query = base_query+'''
from FGXP fg
left join PLAY p on fg.pid=p.pid
left join game g on p.gid=g.gid
join kicker k on k.player = fg.fkicker and g.gid=k.gid
join PLAY pp on pp.pid=p.pid-1 and pp.gid=p.gid
where fg.fgxp='FG' -- not an xp
order by p.pid
'''

df = pd.read_sql(query, cnx, index_col = 'pid')

# dtale.show(df)
df.head(10)
# Out:
#      good  dist  year  seasons  cold  altitude  humid  windy  away_game  \
# pid
# 17      1    43  2000       19     0         0      0      0          0
# 34      1    44  2000       19     0         0      0      0          0
# 52      1    24  2000       19     0         0      0      0          0
# 64      1    44  2000       19     0         0      0      0          0
# 95      1    48  2000       19     0         0      0      0          0
# 241     1    50  2000        6     0         0      1      0          1
# 277     1    25  2000        6     0         0      1      0          1
# 375     1    33  2000        3     0         0      0      0          1
# 387     1    34  2000        1     0         0      0      0          0
# 401     1    38  2000        1     0         0      0      0          0
#
#      postseason  iced  turf  precipitation  pressure
# pid
# 17            0     0     1              0         0
# 34            0     0     1              0         0
# 52            0     0     1              0         0
# 64            0     0     1              0         0
# 95            0     0     1              0         0
# 241           0     1     0              0         0
# 277           0     0     0              0         0
# 375           0     0     1              0         0
# 387           0     0     1              0         0
# 401           0     0     1              0         0

# %% [markdown]
# We assess the correlations: continuous pairs with Pearsons, continuous-binary with pointbiserial, binary pairs with tetrachoric.

# %%
bin_vars = df.drop(['dist','year','seasons'], axis=1).columns.values
con_vars = ['dist','year','seasons']
correlations = []

for v1, v2 in itertools.product(bin_vars,bin_vars):
    if v1>v2:
        try:
            correlations.append([v1,v2,tetrachoric(df[v1],df[v2]),None,'tetrachoric'])
        except:
            print(f'{v1}-{v2}: NaN')

for b1, c2 in itertools.product(bin_vars,con_vars):
    try:
        correlations.append([b1, c2, pointbiserialr(df[b1],df[c2])[0], pointbiserialr(df[b1],df[c2])[1], 'pointbiserial'])
    except Exception as e:
        print(f'{b1}-{c2}: {e}')

for c1, c2 in itertools.product(con_vars,con_vars):
    if c1>c2:
        try:
            correlations.append([c1, c2, pearsonr(df[c1],df[c2])[0], pearsonr(df[c1],df[c2])[1], 'pearsons'])
        except Exception as e:
           print(f'{c1}-{c2}: {e}')


df_corr = pd.DataFrame.from_records(correlations, columns=['cov 1','cov 2', 'corr', 'p','type'])

# %%
df_corr[abs(df_corr['corr'])>0.2].sort_values('corr')
# Out:
#             cov 1          cov 2      corr    p           type
# 33           turf       altitude -1.000000  NaN    tetrachoric
# 7           humid       altitude -0.491142  NaN    tetrachoric
# 42  precipitation       altitude -0.406037  NaN    tetrachoric
# 55           good           dist -0.337741  0.0  pointbiserial
# 11          windy       altitude -0.298940  NaN    tetrachoric
# 34           turf          humid -0.275466  NaN    tetrachoric
# 16          windy           turf -0.256616  NaN    tetrachoric
# 12          windy          humid  0.236658  NaN    tetrachoric
# 17          windy  precipitation  0.264804  NaN    tetrachoric
# 32           turf           cold  0.404744  NaN    tetrachoric
# 21     postseason           cold  0.526256  NaN    tetrachoric
# 43  precipitation          humid  0.682835  NaN    tetrachoric
# 53       pressure           iced  0.762257  NaN    tetrachoric

# %% [markdown]
# From the table above we can see a few things.
# * The strongest (linear) correlations belong to the binary variables
# * turf and altitude have a strong correlation because there is only one stadium at altitude, Denver, and that stadium has a grass surface.
# * Weather conditions are relatively strongly correlated to altitude. Which is a known correlation in meteorology.
# * Precipitation increases humidity, that should be obvious.
# * Postseason games take place in the winter, so are usually played in cold weather.
# * Coaches tend to ice kickers when the game is tight, i.e. pressure situations.
#
# Just to check the continuous variables for non-linear correlations, i'm going to plot them on a scatter matrix.

# %%
# scatter_matrix(df.drop(bin_vars, axis=1), figsize=(15,15))

# %% [markdown]
# Not much we can pull from the above scatters, but lets make a few points.
# * It looks like as kickers get late into their careers, they take fewer long distance attempts.
# * Distance of attempts for each year is relatively stable. Looks like 2008 has a few massively long attempts.
# * Seasons only increasings year-on-year because the span isnt long enough to record retirements. So moving on, we'd expect less correlation.

# %% [markdown]
# ## Reproduction

# %% [markdown]
# In this section we are going to try reproduce the results from the 2 papers mentioned, Going For Three and Choking Under the Pressure. We won't be addressing interaction and multicollinearity just yet, we leave this for the next section.

# %% [markdown]
# ### Going For Three

# %% [markdown]
# Query the database for the data used by Going For Three. i.e. pre-2011.
# Going For Three didn't use the year and seasons variables in their tabulated results, so our first model won't either.

# %%
query = base_query+'''
from FGXP fg
left join PLAY p on fg.pid=p.pid
left join game g on p.gid=g.gid
join kicker k on k.player = fg.fkicker and g.gid=k.gid
join PLAY pp on pp.pid=p.pid-1 and pp.gid=p.gid
where fg.fgxp='FG' -- not an xp
and g.seas <= 2011
order by p.pid
'''

df_gft = pd.read_sql(query, cnx, index_col = 'pid').drop(['seasons','year'], axis=1)
df_gft.head(10)
# Out:
#      good  dist  cold  altitude  humid  windy  away_game  postseason  iced  \
# pid
# 17      1    43     0         0      0      0          0           0     0
# 34      1    44     0         0      0      0          0           0     0
# 52      1    24     0         0      0      0          0           0     0
# 64      1    44     0         0      0      0          0           0     0
# 95      1    48     0         0      0      0          0           0     0
# 241     1    50     0         0      1      0          1           0     1
# 277     1    25     0         0      1      0          1           0     0
# 375     1    33     0         0      0      0          1           0     0
# 387     1    34     0         0      0      0          0           0     0
# 401     1    38     0         0      0      0          0           0     0
#
#      turf  precipitation  pressure
# pid
# 17      1              0         0
# 34      1              0         0
# 52      1              0         0
# 64      1              0         0
# 95      1              0         0
# 241     0              0         0
# 277     0              0         0
# 375     1              0         0
# 387     1              0         0
# 401     1              0         0

# %%
model = glm_sm('good ~ ' + '+'.join(df_gft.drop('good', axis=1).columns.values), df_gft, family=sm.families.Binomial())
result = model.fit(method='newton')
print(result.summary())
base_ll = pd.read_html(result.summary().tables[0].as_html())[0].iloc[4,3]
# Out:
# Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   good   No. Observations:                11901
# Model:                            GLM   Df Residuals:                    11889
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  logit   Scale:                          1.0000
# Method:                        newton   Log-Likelihood:                -5001.9
# Date:                Sat, 22 Feb 2020   Deviance:                       10004.
# Time:                        13:47:44   Pearson chi2:                 1.14e+04
# No. Iterations:                     3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         5.6933      0.139     40.916      0.000       5.421       5.966
# dist             -0.1053      0.003    -35.204      0.000      -0.111      -0.099
# cold             -0.2228      0.057     -3.899      0.000      -0.335      -0.111
# altitude          0.5856      0.158      3.710      0.000       0.276       0.895
# humid            -0.0807      0.055     -1.461      0.144      -0.189       0.028
# windy            -0.2196      0.055     -3.985      0.000      -0.328      -0.112
# away_game        -0.0350      0.050     -0.697      0.486      -0.133       0.063
# postseason       -0.0673      0.054     -1.238      0.216      -0.174       0.039
# iced             -0.1046      0.076     -1.369      0.171      -0.254       0.045
# turf              0.2994      0.055      5.443      0.000       0.192       0.407
# precipitation    -0.1798      0.086     -2.089      0.037      -0.348      -0.011
# pressure         -0.0109      0.108     -0.101      0.920      -0.223       0.201
# =================================================================================

# %% [markdown]
# We now add back in the year and seasons of experience and control for kickers that dont make it in the NFL (so >=50 kicks overall or >=3 seasons at the time of kick). Notice this is a little different from the Going For Three paper. Their criteria threw out a few valid datapoints from experienced kickers at the start of the dataset.

# %%
query = base_query+'''
from FGXP fg
left join PLAY p on fg.pid=p.pid
left join game g on p.gid=g.gid
join kicker k on k.player = fg.fkicker and g.gid=k.gid
join PLAY pp on pp.pid=p.pid-1 and pp.gid=p.gid
where fg.fgxp='FG' -- not an xp
and (
(
    fg.fkicker in (select fkicker from fifty) -- has had at least 50 attempts overall (this keeps only kickers that would end up making it in the NFL)
) or    
(
    k.seas>=3  -- or they had played 3 seasons up to the kick (stops removal of kicks from experienced kickers' kicks from early in the dataset)
)
)
and g.seas <= 2011
order by p.pid
'''

df_gft_ext = pd.read_sql(query, cnx, index_col = 'pid')
df_gft_ext.head(5)
# Out:
#      good  dist  year  seasons  cold  altitude  humid  windy  away_game  \
# pid
# 17      1    43  2000       19     0         0      0      0          0
# 34      1    44  2000       19     0         0      0      0          0
# 52      1    24  2000       19     0         0      0      0          0
# 64      1    44  2000       19     0         0      0      0          0
# 95      1    48  2000       19     0         0      0      0          0
#
#      postseason  iced  turf  precipitation  pressure
# pid
# 17            0     0     1              0         0
# 34            0     0     1              0         0
# 52            0     0     1              0         0
# 64            0     0     1              0         0
# 95            0     0     1              0         0

# %%
print(df_gft_ext['seasons'].describe())
# Out:
# count    11553.000000
# mean         7.908595
# std          5.226298
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         11.000000
# max         26.000000
# Name: seasons, dtype: float64

# %%
model = glm_sm('good ~ '+'+'.join(df_gft_ext.drop('good', axis=1).columns.values), df_gft_ext, family=sm.families.Binomial())
result = model.fit(method='newton')
print(result.summary())
# Out:
# Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   good   No. Observations:                11553
# Model:                            GLM   Df Residuals:                    11539
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                        newton   Log-Likelihood:                -4767.9
# Date:                Sat, 22 Feb 2020   Deviance:                       9535.7
# Time:                        13:47:47   Pearson chi2:                 1.11e+04
# No. Iterations:                     4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -71.3270     15.201     -4.692      0.000    -101.121     -41.533
# dist             -0.1071      0.003    -34.618      0.000      -0.113      -0.101
# year              0.0384      0.008      5.062      0.000       0.024       0.053
# seasons           0.0134      0.005      2.589      0.010       0.003       0.023
# cold             -0.2569      0.059     -4.386      0.000      -0.372      -0.142
# altitude          0.5588      0.159      3.512      0.000       0.247       0.871
# humid            -0.0432      0.057     -0.760      0.448      -0.155       0.068
# windy            -0.2387      0.056     -4.232      0.000      -0.349      -0.128
# away_game        -0.0276      0.052     -0.537      0.591      -0.129       0.073
# postseason       -0.0580      0.056     -1.037      0.300      -0.168       0.052
# iced             -0.1089      0.078     -1.388      0.165      -0.263       0.045
# turf              0.2836      0.056      5.028      0.000       0.173       0.394
# precipitation    -0.1600      0.089     -1.804      0.071      -0.334       0.014
# pressure         -0.0086      0.111     -0.078      0.938      -0.226       0.209
# =================================================================================

# %% [markdown]
# Again, we see that we've arrived at similar results. The psychological variables seem less influential than the environmental and physical factors.

# %% [markdown]
# ### Choking Under the Pressure

# %% [markdown]
# In Choking Under the Pressure, they used similar data now from 2000-2017.
# Lets repeat the modelling with this data, again leaving out the seasons and year covariates and not controlling for >50 kicks

# %%
query = base_query+'''
from FGXP fg
left join PLAY p on fg.pid=p.pid
left join game g on p.gid=g.gid
join kicker k on k.player = fg.fkicker and g.gid=k.gid
join PLAY pp on pp.pid=p.pid-1 and pp.gid=p.gid
where fg.fgxp='FG' -- not an xp
and g.seas <= 2017
order by p.pid
'''

df_cup = pd.read_sql(query, cnx, index_col = 'pid').drop(['seasons','year'], axis=1)
df_cup.head(5)
# Out:
#      good  dist  cold  altitude  humid  windy  away_game  postseason  iced  \
# pid
# 17      1    43     0         0      0      0          0           0     0
# 34      1    44     0         0      0      0          0           0     0
# 52      1    24     0         0      0      0          0           0     0
# 64      1    44     0         0      0      0          0           0     0
# 95      1    48     0         0      0      0          0           0     0
#
#      turf  precipitation  pressure
# pid
# 17      1              0         0
# 34      1              0         0
# 52      1              0         0
# 64      1              0         0
# 95      1              0         0

# %%
model = glm_sm('good ~ '+'+'.join(df_cup.drop(['good'], axis=1).columns.values), df_cup, family=sm.families.Binomial())
result = model.fit(method='newton')
print(result.summary())
# Out:
# Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   good   No. Observations:                18166
# Model:                            GLM   Df Residuals:                    18154
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  logit   Scale:                          1.0000
# Method:                        newton   Log-Likelihood:                -7370.5
# Date:                Sat, 22 Feb 2020   Deviance:                       14741.
# Time:                        13:47:50   Pearson chi2:                 1.74e+04
# No. Iterations:                     3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         5.7011      0.115     49.681      0.000       5.476       5.926
# dist             -0.1016      0.002    -41.712      0.000      -0.106      -0.097
# cold             -0.1731      0.047     -3.661      0.000      -0.266      -0.080
# altitude          0.3789      0.124      3.044      0.002       0.135       0.623
# humid            -0.1050      0.046     -2.286      0.022      -0.195      -0.015
# windy            -0.2226      0.046     -4.803      0.000      -0.313      -0.132
# away_game        -0.0248      0.042     -0.597      0.551      -0.106       0.057
# postseason       -0.0533      0.045     -1.189      0.235      -0.141       0.035
# iced             -0.1318      0.062     -2.130      0.033      -0.253      -0.010
# turf              0.2822      0.045      6.228      0.000       0.193       0.371
# precipitation    -0.2488      0.074     -3.343      0.001      -0.395      -0.103
# pressure         -0.0338      0.087     -0.387      0.699      -0.205       0.137
# =================================================================================

# %% [markdown]
# Again we see similar results. Icing is significant at the 0.05 level as per the paper.

# %% [markdown]
# ## Multicollinearity

# %% [markdown]
# Neither of the aforementioned papers addressed the possibility of multicollinearity, omitted variable bias, and interactions. We shall check the former here.
#
# We remove each of the variables one-by-one and assess the changes in expected values and standard errors of coefficients of the remaining variables. Multicollinearity affects the standard errors of correlated variables and reduces stability when present. However, if a variable is correlated to both the dependent and an independent variable but is omitted, the remaining correlated variable exhibits bias (omitted variable bias or OVB).
#
# We'll be using the extended Going For Three data (i.e. pre-2011 with seasons and year).

# %%
df = df_gft_ext.copy()
from util.summary import Summary

# %% [markdown]
# We can tabulate the results, showing the change in expected coefficients and std errs when we include/exclude each covariate. A summary of the findings is presented below.

# %%
# base result
formula = 'good ~ ' + '+'.join(df.drop(['good'], axis=1).columns.values)
model = glm_sm(formula, df, family=sm.families.Binomial())
result = model.fit(method='irls')
base = Summary(result)
print(base)
# Out:
# Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   good   No. Observations:                11553
# Model:                            GLM   Df Residuals:                    11539
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4767.9
# Date:                Sat, 22 Feb 2020   Deviance:                       9535.7
# Time:                        13:47:50   Pearson chi2:                 1.11e+04
# No. Iterations:                     6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -71.3270     15.201     -4.692      0.000    -101.121     -41.533
# dist             -0.1071      0.003    -34.618      0.000      -0.113      -0.101
# year              0.0384      0.008      5.062      0.000       0.024       0.053
# seasons           0.0134      0.005      2.589      0.010       0.003       0.023
# cold             -0.2569      0.059     -4.386      0.000      -0.372      -0.142
# altitude          0.5588      0.159      3.512      0.000       0.247       0.871
# humid            -0.0432      0.057     -0.760      0.448      -0.155       0.068
# windy            -0.2387      0.056     -4.232      0.000      -0.349      -0.128
# away_game        -0.0276      0.052     -0.537      0.591      -0.129       0.073
# postseason       -0.0580      0.056     -1.037      0.300      -0.168       0.052
# iced             -0.1089      0.078     -1.388      0.165      -0.263       0.045
# turf              0.2836      0.056      5.028      0.000       0.173       0.394
# precipitation    -0.1600      0.089     -1.804      0.071      -0.334       0.014
# pressure         -0.0086      0.111     -0.078      0.938      -0.226       0.209
# =================================================================================

# %%
# removing covariates
removed = {}

for cov in df.drop('good', axis=1).columns.values:
    formula = 'good ~ ' + '+'.join(df.drop(['good',cov], axis=1).columns.values)
    model = glm_sm(formula, df, family=sm.families.Binomial())
    new = Summary(model.fit(method='irls'))
    difference, p = base.compare(new, cov)
    removed[cov] = {'diff':difference, 'p': p, 'summary': new}

# %%
removed['dist']['diff']
# Out:
#                coef with_dist  coef w/o_dist       % coef  se with_dist  \
# Intercept            -71.3270       -47.2287    33.785663        15.201
# altitude               0.5588         0.3011    46.116679         0.159
# away_game             -0.0276        -0.0689  -149.637681         0.052
# cold                  -0.2569        -0.1586    38.263916         0.059
# dist                  -0.1071            NaN          NaN         0.003
# humid                 -0.0432        -0.0289    33.101852         0.057
# iced                  -0.1089        -0.3112  -185.766758         0.078
# postseason            -0.0580         0.0015   102.586207         0.056
# precipitation         -0.1600        -0.1031    35.562500         0.089
# pressure              -0.0086        -0.1144 -1230.232558         0.111
# seasons                0.0134         0.0161   -20.149254         0.005
# turf                   0.2836         0.2310    18.547250         0.056
# windy                 -0.2387        -0.1320    44.700461         0.056
# year                   0.0384         0.0243    36.718750         0.008
#
#                se w/o_dist       % se  P with_dist  P w/o_dist
# Intercept           14.134   7.019275        0.000       0.001
# altitude             0.148   6.918239        0.000       0.042
# away_game            0.048   7.692308        0.591       0.150
# cold                 0.054   8.474576        0.000       0.004
# dist                   NaN        NaN        0.000         NaN
# humid                0.053   7.017544        0.448       0.584
# iced                 0.072   7.692308        0.165       0.000
# postseason           0.052   7.142857        0.300       0.977
# precipitation        0.082   7.865169        0.071       0.208
# pressure             0.103   7.207207        0.938       0.267
# seasons              0.005   0.000000        0.010       0.001
# turf                 0.052   7.142857        0.000       0.000
# windy                0.052   7.142857        0.000       0.011
# year                 0.007  12.500000        0.000       0.001

# %%
print([(cov,round(d['p'],4)) for cov,d in removed.items()])
# Out:
# [('dist', 0.0), ('year', 0.0), ('seasons', 0.0091), ('cold', 0.0), ('altitude', 0.0003), ('humid', 0.4386), ('windy', 0.0), ('away_game', 0.6547), ('postseason', 0.3173), ('iced', 0.1797), ('turf', 0.0), ('precipitation', 0.0736), ('pressure', 1.0)]

# %%
s = removed['year']
print('P(LR|Ho): ',s['p'])
# s.difference
# s.summary
# base.log_likelihood - s['summary'].log_likelihood
# Out:
# P(LR|Ho):  4.200393976021218e-07
# 12.800000000000182

# %% [markdown]
# * dist: OVB on iced and also goes siginificant, OVB with pressure but not significant anyway, maybe OVB with away_game but never significant. LR test rejected null.
# * altitude: Sigificant on its own, no real OVB seen elsewhere. LR test rejected null.
# * away_game: No OVB and not siginificant to begin with. LR test did not reject null.
# * cold: OVB on postseason (which also became significant w/o cold). LR test rejected null.
# * humid: No change on any covariate estimates. LR test did not reject null.
# * iced: OVB on pressure but it never became significant. LR test did not reject null, however it was close.
# * postseason: No change. LR test did not reject null.
# * precipitation: Slight OVB on humidity (theyre correlated), but no changes on significance. LR test did not reject null.
# * pressure: No change. Not even an OVB on iced. LR test did not reject null.
# * seasons: No change. Is significant variable. LR test rejected null.
# * turf: OVB on humidity which also became significant without. LR test rejected null.
# * windy: No change. LR test rejected null.
# * year: No change. LR test rejected null.
#
# Points:
# * cold vs postseason -- postseason is in winter so removing cold resulting in strong OVB on postseason estimate.
# * dist vs iced -- Dist is a strong indicator, and iced kicks are slightly longer on average, hence the OVB.
# * standard errors not largely different from control to treatment, but OVB seems significant for a few combinations.

# %% [markdown]
# ## Iteractions

# %% [markdown]
# From above we can gather that there's no need to necessarily remove any covariates just yet. Although some are most influential than others.
# Now lets look at some interactions of the covariates and see if any of those are important. We first take a graphical approach, using interaction plots with standard error bars to assess interactions we think are reasonably likely to be significant and not spurious. We also perform a likelihood ratio test for each interaction.
#
# We're going to investigate windy\*dist, windy\*cold, postseason\*away_game, postseason\*iced, iced\*away_game, pressure\*iced, pressure\*postseason, pressure\*dist, seasons*dist.

# %%
df = df_gft_ext.copy()

# base result
formula = 'good ~ ' + '+'.join(df.drop(['good'], axis=1).columns.values)
model = glm_sm(formula, df, family=sm.families.Binomial())
result = model.fit(method='irls')
base = Summary(result)
print(base)
# Out:
# Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   good   No. Observations:                11553
# Model:                            GLM   Df Residuals:                    11539
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4767.9
# Date:                Sat, 22 Feb 2020   Deviance:                       9535.7
# Time:                        13:47:54   Pearson chi2:                 1.11e+04
# No. Iterations:                     6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -71.3270     15.201     -4.692      0.000    -101.121     -41.533
# dist             -0.1071      0.003    -34.618      0.000      -0.113      -0.101
# year              0.0384      0.008      5.062      0.000       0.024       0.053
# seasons           0.0134      0.005      2.589      0.010       0.003       0.023
# cold             -0.2569      0.059     -4.386      0.000      -0.372      -0.142
# altitude          0.5588      0.159      3.512      0.000       0.247       0.871
# humid            -0.0432      0.057     -0.760      0.448      -0.155       0.068
# windy            -0.2387      0.056     -4.232      0.000      -0.349      -0.128
# away_game        -0.0276      0.052     -0.537      0.591      -0.129       0.073
# postseason       -0.0580      0.056     -1.037      0.300      -0.168       0.052
# iced             -0.1089      0.078     -1.388      0.165      -0.263       0.045
# turf              0.2836      0.056      5.028      0.000       0.173       0.394
# precipitation    -0.1600      0.089     -1.804      0.071      -0.334       0.014
# pressure         -0.0086      0.111     -0.078      0.938      -0.226       0.209
# =================================================================================

# %%
def get_interactions(covariates):
    interactions = []
    for i,j in itertools.product(covariates,covariates):
        if i>j:
            interactions.append(i+'*'+j)

    return interactions

covariates = df.drop('good', axis=1).columns.values
inters = {}


for interaction in get_interactions(covariates):
    formula = 'good ~ ' + '+'.join(covariates) + '+' + interaction

    model = glm_sm(formula, df, family=sm.families.Binomial())
    cov_summary = Summary(model.fit(method='irls'))
    diff, p = cov_summary.compare(base, interaction) # base has the interaction removed
    inters[interaction] = [interaction, cov_summary.log_likelihood - base.log_likelihood, p, diff]

df_inter = pd.DataFrame.from_records(list(inters.values()), columns=['interaction','delta_ll','p', 'diff']).set_index('interaction')

# %%
df_inter[df_inter['p']<0.2].sort_values('p', ascending=True).loc[:,['delta_ll','p']]
# Out:
#                           delta_ll         p
# interaction
# windy*cold                     3.4  0.009116
# seasons*dist                   3.3  0.010198
# windy*postseason               2.8  0.017960
# humid*cold                     2.7  0.020137
# pressure*altitude              2.7  0.020137
# year*turf                      2.3  0.031972
# windy*humid                    2.3  0.031972
# year*humid                     1.4  0.094264
# seasons*away_game              1.4  0.094264
# iced*humid                     1.2  0.121335
# precipitation*postseason       1.2  0.121335
# year*windy                     1.1  0.138011
# iced*away_game                 1.0  0.157299
# humid*dist                     0.9  0.179712

# %% [markdown]
# #### Cold & Windy

# %%
fig = interaction_plot(x=df['cold'].values,trace=df['windy'].values,response=df['good'].values, xlabel='cold', legendtitle='windy', ylabel='good', errorbars=True)
plt.show()

fig = interaction_plot(x=df['windy'].values,trace=df['cold'].values,response=df['good'].values, xlabel='windy', legendtitle='cold', ylabel='good', errorbars=True)
plt.show()

# %%
print('P(LR|Ho): ',df_inter.loc['windy*cold', 'p'])
df_inter.loc['windy*cold','diff']
# Out:
# P(LR|Ho):  0.00911578725251203
#                coef with_windy*cold  coef w/o_windy*cold      % coef  \
# Intercept                  -69.5639             -71.3270   -2.534504
# altitude                     0.5684               0.5588    1.688951
# away_game                   -0.0319              -0.0276   13.479624
# cold                        -0.1634              -0.2569  -57.221542
# dist                        -0.1074              -0.1071    0.279330
# humid                       -0.0332              -0.0432  -30.120482
# iced                        -0.1082              -0.1089   -0.646950
# postseason                  -0.0489              -0.0580  -18.609407
# precipitation               -0.1623              -0.1600    1.417129
# pressure                    -0.0033              -0.0086 -160.606061
# seasons                      0.0137               0.0134    2.189781
# turf                         0.2818               0.2836   -0.638751
# windy                       -0.1329              -0.2387  -79.608728
# windy:cold                  -0.2991                  NaN         NaN
# year                         0.0375               0.0384   -2.400000
#
#                se with_windy*cold  se w/o_windy*cold       % se  \
# Intercept                  15.219             15.201   0.118273
# altitude                    0.159              0.159   0.000000
# away_game                   0.052              0.052   0.000000
# cold                        0.069              0.059  14.492754
# dist                        0.003              0.003   0.000000
# humid                       0.057              0.057   0.000000
# iced                        0.079              0.078   1.265823
# postseason                  0.056              0.056   0.000000
# precipitation               0.089              0.089   0.000000
# pressure                    0.111              0.111   0.000000
# seasons                     0.005              0.005   0.000000
# turf                        0.056              0.056   0.000000
# windy                       0.070              0.056  20.000000
# windy:cold                  0.115                NaN        NaN
# year                        0.008              0.008   0.000000
#
#                P with_windy*cold  P w/o_windy*cold
# Intercept                  0.000             0.000
# altitude                   0.000             0.000
# away_game                  0.536             0.591
# cold                       0.018             0.000
# dist                       0.000             0.000
# humid                      0.561             0.448
# iced                       0.168             0.165
# postseason                 0.384             0.300
# precipitation              0.068             0.071
# pressure                   0.976             0.938
# seasons                    0.008             0.010
# turf                       0.000             0.000
# windy                      0.057             0.000
# windy:cold                 0.009               NaN
# year                       0.000             0.000

# %% [markdown]
# This had the biggest effect on the log-likelihood. The interaction appears significant and the interaction plot seems to support the hypothesis. It looks like the combination of cold and windy is greater than the sum of their parts.

# %% [markdown]
# #### Postseason & Away games

# %%
fig = interaction_plot(x=df['postseason'].values,trace=df['away_game'].values,response=df['good'].values, xlabel='postseason', legendtitle='away_game', ylabel='good', errorbars=True)
plt.show()

fig = interaction_plot(x=df['away_game'].values,trace=df['postseason'].values,response=df['good'].values, xlabel='away_game', legendtitle='postseason', ylabel='good', errorbars=True)
plt.show()

# %%
print('P(LR|Ho): ',df_inter.loc['postseason*away_game', 'p'])
df_inter.loc['postseason*away_game', 'diff']
# Out:
# P(LR|Ho):  0.20590321073227089
#                       coef with_postseason*away_game  \
# Intercept                                   -71.3256
# altitude                                      0.5619
# away_game                                     0.0400
# cold                                         -0.2578
# dist                                         -0.1072
# humid                                        -0.0434
# iced                                         -0.1088
# postseason                                    0.0066
# postseason:away_game                         -0.1301
# precipitation                                -0.1613
# pressure                                     -0.0111
# seasons                                       0.0133
# turf                                          0.2855
# windy                                        -0.2403
# year                                          0.0384
#
#                       coef w/o_postseason*away_game      % coef  \
# Intercept                                  -71.3270   -0.001963
# altitude                                     0.5588    0.551700
# away_game                                   -0.0276  169.000000
# cold                                        -0.2569    0.349108
# dist                                        -0.1071    0.093284
# humid                                       -0.0432    0.460829
# iced                                        -0.1089   -0.091912
# postseason                                  -0.0580  978.787879
# postseason:away_game                            NaN         NaN
# precipitation                               -0.1600    0.805952
# pressure                                    -0.0086   22.522523
# seasons                                      0.0134   -0.751880
# turf                                         0.2836    0.665499
# windy                                       -0.2387    0.665834
# year                                         0.0384    0.000000
#
#                       se with_postseason*away_game  \
# Intercept                                   15.202
# altitude                                     0.159
# away_game                                    0.074
# cold                                         0.059
# dist                                         0.003
# humid                                        0.057
# iced                                         0.078
# postseason                                   0.076
# postseason:away_game                         0.103
# precipitation                                0.089
# pressure                                     0.111
# seasons                                      0.005
# turf                                         0.056
# windy                                        0.056
# year                                         0.008
#
#                       se w/o_postseason*away_game       % se  \
# Intercept                                  15.201   0.006578
# altitude                                    0.159   0.000000
# away_game                                   0.052  29.729730
# cold                                        0.059   0.000000
# dist                                        0.003   0.000000
# humid                                       0.057   0.000000
# iced                                        0.078   0.000000
# postseason                                  0.056  26.315789
# postseason:away_game                          NaN        NaN
# precipitation                               0.089   0.000000
# pressure                                    0.111   0.000000
# seasons                                     0.005   0.000000
# turf                                        0.056   0.000000
# windy                                       0.056   0.000000
# year                                        0.008   0.000000
#
#                       P with_postseason*away_game  P w/o_postseason*away_game
# Intercept                                   0.000                       0.000
# altitude                                    0.000                       0.000
# away_game                                   0.591                       0.591
# cold                                        0.000                       0.000
# dist                                        0.000                       0.000
# humid                                       0.446                       0.448
# iced                                        0.165                       0.165
# postseason                                  0.931                       0.300
# postseason:away_game                        0.207                         NaN
# precipitation                               0.069                       0.071
# pressure                                    0.921                       0.938
# seasons                                     0.010                       0.010
# turf                                        0.000                       0.000
# windy                                       0.000                       0.000
# year                                        0.000                       0.000

# %% [markdown]
# Neither of the main effects were significant and neither is the interaction. We're talking about small interaction effects as the error bars kind of consume the difference.

# %% [markdown]
# #### Iced & Away games

# %%
fig = interaction_plot(x=df['iced'].values,trace=df['away_game'].values,response=df['good'].values, xlabel='iced', legendtitle='away_game', ylabel='good', errorbars=True)
plt.show()

fig = interaction_plot(x=df['away_game'].values,trace=df['iced'].values,response=df['good'].values, xlabel='away_game', legendtitle='iced', ylabel='good', errorbars=True)
plt.show()

print(df.groupby(['iced', 'away_game']).size())
# Out:
# iced  away_game
# 0     0            5204
#       1            4907
# 1     0             766
#       1             676
# dtype: int64

# %%
print('P(LR|Ho): ',df_inter.loc['iced*away_game', 'p'])
df_inter.loc['iced*away_game', 'diff']
# Out:
# P(LR|Ho):  0.15729920705028105
#                 coef with_iced*away_game  coef w/o_iced*away_game     % coef  \
# Intercept                       -71.5072                 -71.3270   0.252003
# altitude                          0.5542                   0.5588  -0.830025
# away_game                        -0.0571                  -0.0276  51.663748
# cold                             -0.2564                  -0.2569  -0.195008
# dist                             -0.1072                  -0.1071   0.093284
# humid                            -0.0428                  -0.0432  -0.934579
# iced                             -0.2067                  -0.1089  47.314949
# iced:away_game                    0.2080                      NaN        NaN
# postseason                       -0.0578                  -0.0580  -0.346021
# precipitation                    -0.1619                  -0.1600   1.173564
# pressure                         -0.0089                  -0.0086   3.370787
# seasons                           0.0133                   0.0134  -0.751880
# turf                              0.2844                   0.2836   0.281294
# windy                            -0.2394                  -0.2387   0.292398
# year                              0.0385                   0.0384   0.259740
#
#                 se with_iced*away_game  se w/o_iced*away_game       % se  \
# Intercept                       15.203                 15.201   0.013155
# altitude                         0.159                  0.159   0.000000
# away_game                        0.056                  0.052   7.142857
# cold                             0.059                  0.059   0.000000
# dist                             0.003                  0.003   0.000000
# humid                            0.057                  0.057   0.000000
# iced                             0.104                  0.078  25.000000
# iced:away_game                   0.148                    NaN        NaN
# postseason                       0.056                  0.056   0.000000
# precipitation                    0.089                  0.089   0.000000
# pressure                         0.111                  0.111   0.000000
# seasons                          0.005                  0.005   0.000000
# turf                             0.056                  0.056   0.000000
# windy                            0.056                  0.056   0.000000
# year                             0.008                  0.008   0.000000
#
#                 P with_iced*away_game  P w/o_iced*away_game
# Intercept                       0.000                 0.000
# altitude                        0.000                 0.000
# away_game                       0.305                 0.591
# cold                            0.000                 0.000
# dist                            0.000                 0.000
# humid                           0.452                 0.448
# iced                            0.047                 0.165
# iced:away_game                  0.160                   NaN
# postseason                      0.301                 0.300
# precipitation                   0.068                 0.071
# pressure                        0.936                 0.938
# seasons                         0.010                 0.010
# turf                            0.000                 0.000
# windy                           0.000                 0.000
# year                            0.000                 0.000

# %% [markdown]
# What about the iced*away_game interaction. Error bars consume the any interaction here, not that there looked like much anyway.

# %% [markdown]
# #### Iced & Pressure

# %%
fig = interaction_plot(x=df['iced'].values,trace=df['pressure'].values,response=df['good'].values, xlabel='iced', legendtitle='pressure', ylabel='good', errorbars=True)
plt.show()

fig = interaction_plot(x=df['pressure'].values,trace=df['iced'].values,response=df['good'].values, xlabel='pressure', legendtitle='iced', ylabel='good', errorbars=True)
plt.show()

print(df.groupby(['iced', 'pressure']).size())
# Out:
# iced  pressure
# 0     0           9836
#       1            275
# 1     0           1052
#       1            390
# dtype: int64

# %%
print('P(LR|Ho): ',df_inter.loc['pressure*iced', 'p'])
df_inter.loc['pressure*iced', 'diff']
# Out:
# P(LR|Ho):  0.5270892568657259
#                coef with_pressure*iced  coef w/o_pressure*iced      % coef  \
# Intercept                     -71.2743                -71.3270   -0.073940
# altitude                        0.5598                  0.5588    0.178635
# away_game                      -0.0274                 -0.0276   -0.729927
# cold                           -0.2567                 -0.2569   -0.077912
# dist                           -0.1072                 -0.1071    0.093284
# humid                          -0.0436                 -0.0432    0.917431
# iced                           -0.0928                 -0.1089  -17.349138
# postseason                     -0.0582                 -0.0580    0.343643
# precipitation                  -0.1589                 -0.1600   -0.692259
# pressure                        0.0489                 -0.0086  117.586912
# pressure:iced                  -0.1101                     NaN         NaN
# seasons                         0.0134                  0.0134    0.000000
# turf                            0.2840                  0.2836    0.140845
# windy                          -0.2391                 -0.2387    0.167294
# year                            0.0384                  0.0384    0.000000
#
#                se with_pressure*iced  se w/o_pressure*iced       % se  \
# Intercept                     15.202                15.201   0.006578
# altitude                       0.159                 0.159   0.000000
# away_game                      0.052                 0.052   0.000000
# cold                           0.059                 0.059   0.000000
# dist                           0.003                 0.003   0.000000
# humid                          0.057                 0.057   0.000000
# iced                           0.085                 0.078   8.235294
# postseason                     0.056                 0.056   0.000000
# precipitation                  0.089                 0.089   0.000000
# pressure                       0.162                 0.111  31.481481
# pressure:iced                  0.223                   NaN        NaN
# seasons                        0.005                 0.005   0.000000
# turf                           0.056                 0.056   0.000000
# windy                          0.056                 0.056   0.000000
# year                           0.008                 0.008   0.000000
#
#                P with_pressure*iced  P w/o_pressure*iced
# Intercept                     0.000                0.000
# altitude                      0.000                0.000
# away_game                     0.595                0.591
# cold                          0.000                0.000
# dist                          0.000                0.000
# humid                         0.443                0.448
# iced                          0.276                0.165
# postseason                    0.298                0.300
# precipitation                 0.073                0.071
# pressure                      0.762                0.938
# pressure:iced                 0.621                  NaN
# seasons                       0.010                0.010
# turf                          0.000                0.000
# windy                         0.000                0.000
# year                          0.000                0.000

# %% [markdown]
# Not much pressure data to work with here, which is why the error bars are so wide. We can't say for certain if there is an interaction and the LR test suggests it is a weak predictor.

# %% [markdown]
# #### Distance & Wind

# %%
df_5 = df.copy()
df_5['dist'] = 5*round(df_5['dist']/5)
# df_5['dist'] = df_5['dist']>40

# df_5 = df_5[df_5['dist']<=50]


fig = interaction_plot(x=df_5['dist'].values,trace=df_5['windy'].values,response=df_5['good'].values, xlabel='dist', legendtitle='windy', ylabel='good', errorbars=True)
plt.show()

print(df_5.groupby(['windy', 'dist']).size())
# Out:
# windy  dist
# 0      20.0     728
#        25.0    1128
#        30.0    1142
#        35.0    1157
#        40.0    1295
#        45.0    1209
#        50.0    1000
#        55.0     298
#        60.0      39
#        65.0      11
#        70.0       1
# 1      20.0     324
#        25.0     556
#        30.0     531
#        35.0     536
#        40.0     580
#        45.0     536
#        50.0     368
#        55.0      96
#        60.0      14
#        65.0       2
#        70.0       1
#        75.0       1
# dtype: int64

# %%
print('P(LR|Ho): ',df_inter.loc['windy*dist', 'p'])
df_inter.loc['windy*dist', 'diff']
# Out:
# P(LR|Ho):  0.6547208460194578
#                coef with_windy*dist  coef w/o_windy*dist     % coef  \
# Intercept                  -71.3185             -71.3270  -0.011918
# altitude                     0.5584               0.5588  -0.071633
# away_game                   -0.0276              -0.0276  -0.000000
# cold                        -0.2572              -0.2569   0.116641
# dist                        -0.1067              -0.1071  -0.374883
# humid                       -0.0431              -0.0432  -0.232019
# iced                        -0.1088              -0.1089  -0.091912
# postseason                  -0.0581              -0.0580   0.172117
# precipitation               -0.1601              -0.1600   0.062461
# pressure                    -0.0091              -0.0086   5.494505
# seasons                      0.0134               0.0134   0.000000
# turf                         0.2836               0.2836   0.000000
# windy                       -0.1874              -0.2387 -27.374600
# windy:dist                  -0.0012                  NaN        NaN
# year                         0.0384               0.0384   0.000000
#
#                se with_windy*dist  se w/o_windy*dist       % se  \
# Intercept                  15.202             15.201   0.006578
# altitude                    0.159              0.159   0.000000
# away_game                   0.052              0.052   0.000000
# cold                        0.059              0.059   0.000000
# dist                        0.004              0.003  25.000000
# humid                       0.057              0.057   0.000000
# iced                        0.078              0.078   0.000000
# postseason                  0.056              0.056   0.000000
# precipitation               0.089              0.089   0.000000
# pressure                    0.111              0.111   0.000000
# seasons                     0.005              0.005   0.000000
# turf                        0.056              0.056   0.000000
# windy                       0.274              0.056  79.562044
# windy:dist                  0.007                NaN        NaN
# year                        0.008              0.008   0.000000
#
#                P with_windy*dist  P w/o_windy*dist
# Intercept                  0.000             0.000
# altitude                   0.000             0.000
# away_game                  0.592             0.591
# cold                       0.000             0.000
# dist                       0.000             0.000
# humid                      0.449             0.448
# iced                       0.165             0.165
# postseason                 0.299             0.300
# precipitation              0.071             0.071
# pressure                   0.935             0.938
# seasons                    0.010             0.010
# turf                       0.000             0.000
# windy                      0.494             0.000
# windy:dist                 0.848               NaN
# year                       0.000             0.000

# %% [markdown]
# Interestingly enough, pre-2011, the interaction between distance and wind seems negligible. But in the mid-ranges above 40 yards there does seem to be a divergence, above 50 yards there is just not enough data to conclude anything.

# %% [markdown]
# #### Iced & Postseason

# %%
fig = interaction_plot(x=df['iced'].values,trace=df['postseason'].values,response=df['good'].values, xlabel='iced', legendtitle='postseason', ylabel='good', errorbars=True)
plt.show()

fig = interaction_plot(x=df['postseason'].values,trace=df['iced'].values,response=df['good'].values, xlabel='postseason', legendtitle='iced', ylabel='good', errorbars=True)
plt.show()

print(df.groupby(['iced', 'postseason']).aggregate(lambda x: np.mean(x)).loc[:,'good'])
# Out:
# iced  postseason
# 0     0             0.824501
#       1             0.813131
# 1     0             0.768156
#       1             0.758953
# Name: good, dtype: float64

# %%
print('P(LR|Ho): ',df_inter.loc['postseason*iced', 'p'])
df_inter.loc['postseason*iced', 'diff']
# Out:
# P(LR|Ho):  1.0
#                  coef with_postseason*iced  coef w/o_postseason*iced  \
# Intercept                         -71.3321                  -71.3270
# altitude                            0.5588                    0.5588
# away_game                          -0.0276                   -0.0276
# cold                               -0.2570                   -0.2569
# dist                               -0.1071                   -0.1071
# humid                              -0.0432                   -0.0432
# iced                               -0.1135                   -0.1089
# postseason                         -0.0592                   -0.0580
# postseason:iced                     0.0090                       NaN
# precipitation                      -0.1601                   -0.1600
# pressure                           -0.0087                   -0.0086
# seasons                             0.0134                    0.0134
# turf                                0.2837                    0.2836
# windy                              -0.2387                   -0.2387
# year                                0.0384                    0.0384
#
#                    % coef  se with_postseason*iced  se w/o_postseason*iced  \
# Intercept        0.007150                   15.202                  15.201
# altitude         0.000000                    0.159                   0.159
# away_game       -0.000000                    0.052                   0.052
# cold             0.038911                    0.059                   0.059
# dist            -0.000000                    0.003                   0.003
# humid           -0.000000                    0.057                   0.057
# iced             4.052863                    0.109                   0.078
# postseason       2.027027                    0.060                   0.056
# postseason:iced       NaN                    0.147                     NaN
# precipitation    0.062461                    0.089                   0.089
# pressure         1.149425                    0.111                   0.111
# seasons          0.000000                    0.005                   0.005
# turf             0.035249                    0.056                   0.056
# windy           -0.000000                    0.056                   0.056
# year             0.000000                    0.008                   0.008
#
#                       % se  P with_postseason*iced  P w/o_postseason*iced
# Intercept         0.006578                   0.000                  0.000
# altitude          0.000000                   0.000                  0.000
# away_game         0.000000                   0.592                  0.591
# cold              0.000000                   0.000                  0.000
# dist              0.000000                   0.000                  0.000
# humid             0.000000                   0.448                  0.448
# iced             28.440367                   0.297                  0.165
# postseason        6.666667                   0.320                  0.300
# postseason:iced        NaN                   0.951                    NaN
# precipitation     0.000000                   0.071                  0.071
# pressure          0.000000                   0.938                  0.938
# seasons           0.000000                   0.010                  0.010
# turf              0.000000                   0.000                  0.000
# windy             0.000000                   0.000                  0.000
# year              0.000000                   0.000                  0.000

# %% [markdown]
# Clearly no interaction here.

# %% [markdown]
# #### Pressure & Postseason

# %%
fig = interaction_plot(x=df['pressure'].values,trace=df['postseason'].values,response=df['good'].values, xlabel='pressure', legendtitle='postseason', ylabel='good', errorbars=True)
plt.show()

fig = interaction_plot(x=df['postseason'].values,trace=df['pressure'].values,response=df['good'].values, xlabel='postseason', legendtitle='pressure', ylabel='good', errorbars=True)
plt.show()

print(df.groupby(['pressure', 'postseason']).aggregate(lambda x: np.mean(x)).loc[:,'good'])
# Out:
# pressure  postseason
# 0         0             0.818826
#           1             0.810067
# 1         0             0.792994
#           1             0.749288
# Name: good, dtype: float64

# %%
print('P(LR|Ho): ',df_inter.loc['pressure*postseason', 'p'])
df_inter.loc['pressure*postseason', 'diff']
# Out:
# P(LR|Ho):  0.37109336952291505
#                      coef with_pressure*postseason  \
# Intercept                                 -71.1972
# altitude                                    0.5594
# away_game                                  -0.0284
# cold                                       -0.2566
# dist                                       -0.1071
# humid                                      -0.0431
# iced                                       -0.1095
# postseason                                 -0.0461
# precipitation                              -0.1590
# pressure                                    0.0933
# pressure:postseason                        -0.1862
# seasons                                     0.0134
# turf                                        0.2837
# windy                                      -0.2385
# year                                        0.0383
#
#                      coef w/o_pressure*postseason      % coef  \
# Intercept                                -71.3270   -0.182311
# altitude                                   0.5588    0.107258
# away_game                                 -0.0276    2.816901
# cold                                      -0.2569   -0.116913
# dist                                      -0.1071   -0.000000
# humid                                     -0.0432   -0.232019
# iced                                      -0.1089    0.547945
# postseason                                -0.0580  -25.813449
# precipitation                             -0.1600   -0.628931
# pressure                                  -0.0086  109.217578
# pressure:postseason                           NaN         NaN
# seasons                                    0.0134    0.000000
# turf                                       0.2836    0.035249
# windy                                     -0.2387   -0.083857
# year                                       0.0384   -0.261097
#
#                      se with_pressure*postseason  se w/o_pressure*postseason  \
# Intercept                                 15.203                      15.201
# altitude                                   0.159                       0.159
# away_game                                  0.052                       0.052
# cold                                       0.059                       0.059
# dist                                       0.003                       0.003
# humid                                      0.057                       0.057
# iced                                       0.078                       0.078
# postseason                                 0.058                       0.056
# precipitation                              0.089                       0.089
# pressure                                   0.161                       0.111
# pressure:postseason                        0.210                         NaN
# seasons                                    0.005                       0.005
# turf                                       0.056                       0.056
# windy                                      0.056                       0.056
# year                                       0.008                       0.008
#
#                           % se  P with_pressure*postseason  \
# Intercept             0.013155                       0.000
# altitude              0.000000                       0.000
# away_game             0.000000                       0.581
# cold                  0.000000                       0.000
# dist                  0.000000                       0.000
# humid                 0.000000                       0.449
# iced                  0.000000                       0.163
# postseason            3.448276                       0.422
# precipitation         0.000000                       0.073
# pressure             31.055901                       0.563
# pressure:postseason        NaN                       0.376
# seasons               0.000000                       0.010
# turf                  0.000000                       0.000
# windy                 0.000000                       0.000
# year                  0.000000                       0.000
#
#                      P w/o_pressure*postseason
# Intercept                                0.000
# altitude                                 0.000
# away_game                                0.591
# cold                                     0.000
# dist                                     0.000
# humid                                    0.448
# iced                                     0.165
# postseason                               0.300
# precipitation                            0.071
# pressure                                 0.938
# pressure:postseason                        NaN
# seasons                                  0.010
# turf                                     0.000
# windy                                    0.000
# year                                     0.000

# %% [markdown]
# The LR test suggests the interaction doesnt help the model and subsequently the p value is insignificant. Probably not much of an interaction here.

# %% [markdown]
# #### Pressure & Distance

# %%
fig = interaction_plot(x=df_5['dist'].values,trace=df_5['pressure'].values,response=df_5['good'].values, xlabel='dist', legendtitle='pressure', ylabel='good', errorbars=True)
plt.show()

print(df_5.groupby(['pressure', 'dist']).aggregate(lambda x: np.mean(x)).loc[:,'good'])
# Out:
# pressure  dist
# 0         20.0    0.982213
#           25.0    0.963953
#           30.0    0.904249
#           35.0    0.852665
#           40.0    0.801466
#           45.0    0.699023
#           50.0    0.606583
#           55.0    0.526761
#           60.0    0.210526
#           65.0    0.083333
#           70.0    0.000000
#           75.0    0.000000
# 1         20.0    1.000000
#           25.0    0.933333
#           30.0    0.885417
#           35.0    0.826531
#           40.0    0.764706
#           45.0    0.728972
#           50.0    0.619565
#           55.0    0.487179
#           60.0    0.266667
#           65.0    0.000000
# Name: good, dtype: float64

# %%
print('P(LR|Ho): ',df_inter.loc['pressure*dist', 'p'])
df_inter.loc['pressure*dist', 'diff']
# Out:
# P(LR|Ho):  0.37109336952291505
#                coef with_pressure*dist  coef w/o_pressure*dist     % coef  \
# Intercept                     -71.2727                -71.3270  -0.076186
# altitude                        0.5570                  0.5588  -0.323160
# away_game                      -0.0278                 -0.0276   0.719424
# cold                           -0.2572                 -0.2569   0.116641
# dist                           -0.1078                 -0.1071   0.649351
# humid                          -0.0432                 -0.0432  -0.000000
# iced                           -0.1063                 -0.1089  -2.445908
# postseason                     -0.0581                 -0.0580   0.172117
# precipitation                  -0.1607                 -0.1600   0.435594
# pressure                       -0.4172                 -0.0086  97.938639
# pressure:dist                   0.0095                     NaN        NaN
# seasons                         0.0134                  0.0134   0.000000
# turf                            0.2837                  0.2836   0.035249
# windy                          -0.2383                 -0.2387  -0.167856
# year                            0.0384                  0.0384   0.000000
#
#                se with_pressure*dist  se w/o_pressure*dist       % se  \
# Intercept                     15.200                15.201  -0.006579
# altitude                       0.159                 0.159   0.000000
# away_game                      0.052                 0.052   0.000000
# cold                           0.059                 0.059   0.000000
# dist                           0.003                 0.003   0.000000
# humid                          0.057                 0.057   0.000000
# iced                           0.078                 0.078   0.000000
# postseason                     0.056                 0.056   0.000000
# precipitation                  0.089                 0.089   0.000000
# pressure                       0.513                 0.111  78.362573
# pressure:dist                  0.012                   NaN        NaN
# seasons                        0.005                 0.005   0.000000
# turf                           0.056                 0.056   0.000000
# windy                          0.056                 0.056   0.000000
# year                           0.008                 0.008   0.000000
#
#                P with_pressure*dist  P w/o_pressure*dist
# Intercept                     0.000                0.000
# altitude                      0.000                0.000
# away_game                     0.589                0.591
# cold                          0.000                0.000
# dist                          0.000                0.000
# humid                         0.448                0.448
# iced                          0.175                0.165
# postseason                    0.299                0.300
# precipitation                 0.070                0.071
# pressure                      0.416                0.938
# pressure:dist                 0.416                  NaN
# seasons                       0.010                0.010
# turf                          0.000                0.000
# windy                         0.000                0.000
# year                          0.000                0.000

# %% [markdown]
# Not much going on here. And we just dont have enough pressure data points to work with.

# %% [markdown]
# #### Seasons & Distance

# %%
df_5['seasons'] = 5*round(df_5['seasons']/5)

fig = interaction_plot(x=df_5['dist'].values,trace=df_5['seasons'].values,response=df_5['good'].values, xlabel='dist', legendtitle='seasons', ylabel='good', errorbars=True)
plt.show()

print(df_5.groupby(['seasons', 'dist']).aggregate(lambda x: np.mean(x)).loc[:,'good'])
# Out:
# seasons  dist
# 0.0      20.0    0.969466
#          25.0    0.958140
#          30.0    0.888889
#          35.0    0.824903
#          40.0    0.767176
#          45.0    0.679842
#          50.0    0.550296
#          55.0    0.588235
#          60.0    0.200000
#          65.0    0.000000
#          70.0    0.000000
# 5.0      20.0    0.981221
#          25.0    0.954351
#          30.0    0.897015
#          35.0    0.841958
#          40.0    0.789542
#          45.0    0.703104
#          50.0    0.600340
#          55.0    0.497110
#          60.0    0.296296
#          65.0    0.000000
# 10.0     20.0    0.982079
#          25.0    0.962306
#          30.0    0.911392
#          35.0    0.849315
#          40.0    0.803719
#          45.0    0.706311
#          50.0    0.636872
#          55.0    0.515385
#          60.0    0.166667
#          65.0    0.142857
#          70.0    0.000000
#          75.0    0.000000
# 15.0     20.0    0.993333
#          25.0    0.990385
#          30.0    0.911330
#          35.0    0.875706
#          40.0    0.845188
#          45.0    0.707763
#          50.0    0.640449
#          55.0    0.644444
#          60.0    0.000000
#          65.0    0.000000
# 20.0     20.0    1.000000
#          25.0    1.000000
#          30.0    0.912088
#          35.0    0.934783
#          40.0    0.830000
#          45.0    0.700935
#          50.0    0.600000
#          55.0    0.333333
#          60.0    0.000000
# 25.0     20.0    1.000000
#          25.0    0.850000
#          30.0    0.947368
#          35.0    1.000000
#          40.0    0.800000
#          45.0    0.692308
#          50.0    0.200000
# Name: good, dtype: float64

# %%
print('P(LR|Ho): ',df_inter.loc['seasons*dist', 'p'])
df_inter.loc['seasons*dist', 'diff']
# Out:
# P(LR|Ho):  0.010197876776248603
#                coef with_seasons*dist  coef w/o_seasons*dist     % coef  \
# Intercept                    -71.8962               -71.3270   0.791697
# altitude                       0.5543                 0.5588  -0.811835
# away_game                     -0.0301                -0.0276   8.305648
# cold                          -0.2578                -0.2569   0.349108
# dist                          -0.0952                -0.1071 -12.500000
# humid                         -0.0421                -0.0432  -2.612827
# iced                          -0.1126                -0.1089   3.285968
# postseason                    -0.0598                -0.0580   3.010033
# precipitation                 -0.1586                -0.1600  -0.882724
# pressure                      -0.0064                -0.0086 -34.375000
# seasons                        0.0803                 0.0134  83.312578
# seasons:dist                  -0.0016                    NaN        NaN
# turf                           0.2849                 0.2836   0.456300
# windy                         -0.2405                -0.2387   0.748441
# year                           0.0384                 0.0384   0.000000
#
#                se with_seasons*dist  se w/o_seasons*dist       % se  \
# Intercept                    15.203               15.201   0.013155
# altitude                      0.159                0.159   0.000000
# away_game                     0.052                0.052   0.000000
# cold                          0.059                0.059   0.000000
# dist                          0.006                0.003  50.000000
# humid                         0.057                0.057   0.000000
# iced                          0.078                0.078   0.000000
# postseason                    0.056                0.056   0.000000
# precipitation                 0.089                0.089   0.000000
# pressure                      0.111                0.111   0.000000
# seasons                       0.027                0.005  81.481481
# seasons:dist                  0.001                  NaN        NaN
# turf                          0.056                0.056   0.000000
# windy                         0.056                0.056   0.000000
# year                          0.008                0.008   0.000000
#
#                P with_seasons*dist  P w/o_seasons*dist
# Intercept                    0.000               0.000
# altitude                     0.000               0.000
# away_game                    0.560               0.591
# cold                         0.000               0.000
# dist                         0.000               0.000
# humid                        0.459               0.448
# iced                         0.151               0.165
# postseason                   0.285               0.300
# precipitation                0.073               0.071
# pressure                     0.954               0.938
# seasons                      0.003               0.010
# seasons:dist                 0.012                 NaN
# turf                         0.000               0.000
# windy                        0.000               0.000
# year                         0.000               0.000

# %% [markdown]
# Error bars are too wide here to say much from the interaction plot. But the interaction seems to be significant enough. Slight negative effect for an older kicker at distance.

# %% [markdown]
# Points:
# * It's tough to separate the effect of postseason games and the cold. There's never a postseason game during the warmer months so maybe we'll have to do an observational study for this. My thoughts are its the cold doing the work, because the OVB when leaving out cold is significant on the postseason coefficient but not other way around.
#
# * After all that, we're going to include the interaction effects of cold\*windy (possible), postseason\*away_game (doubtful), wind\*dist (doubtful), pressure\*iced (possible), seasons\*dist (possible). A few of these were less than convincing, but for the sake of completeness we will include them.

# %% [markdown]
# ## Modelling

# %% [markdown]
# We now add in the interactions and train a model using data pre-2011, as per Going For Three, to see how the results compare now.

# %%
query = base_query+'''
from FGXP fg
left join PLAY p on fg.pid=p.pid
left join game g on p.gid=g.gid
join kicker k on k.player = fg.fkicker and g.gid=k.gid
join PLAY pp on pp.pid=p.pid-1 and pp.gid=p.gid
where fg.fgxp='FG' -- not an xp
and (
(
    fg.fkicker in (select fkicker from fifty) -- has had at least 50 attempts overall (this keeps only kickers that would end up making it in the NFL)
) or    
(
    k.seas>=3  -- or they had played 4 seasons up to the kick (stops removal of kicks from experienced kickers' kicks from early in the dataset)
)
)
and g.seas <= 2011
order by p.pid
'''

df = pd.read_sql(query, cnx, index_col = 'pid')
df.head(5)
# Out:
#      good  dist  year  seasons  cold  altitude  humid  windy  away_game  \
# pid
# 17      1    43  2000       19     0         0      0      0          0
# 34      1    44  2000       19     0         0      0      0          0
# 52      1    24  2000       19     0         0      0      0          0
# 64      1    44  2000       19     0         0      0      0          0
# 95      1    48  2000       19     0         0      0      0          0
#
#      postseason  iced  turf  precipitation  pressure
# pid
# 17            0     0     1              0         0
# 34            0     0     1              0         0
# 52            0     0     1              0         0
# 64            0     0     1              0         0
# 95            0     0     1              0         0

# %%
df_test = df.sample(frac=0.1)
df_train = df.drop(df_test.index)

# %%
print('Train: ', df_test['good'].value_counts(normalize=True)[1])
print('Test: ', df_train['good'].value_counts(normalize=True)[1])
# Out:
# Train:  0.8025974025974026
# Test:  0.8128486247355261

# %%
# base result without interactions
formula = 'good ~ ' + '+'.join(df_train.drop(['good'], axis=1).columns.values)
model = glm_sm(formula, df_train, family=sm.families.Binomial())
base_result = model.fit(method='irls')
base = Summary(base_result)
print(base.result.summary())
# Out:
# Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   good   No. Observations:                10398
# Model:                            GLM   Df Residuals:                    10384
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4262.7
# Date:                Sat, 22 Feb 2020   Deviance:                       8525.4
# Time:                        13:48:24   Pearson chi2:                 9.96e+03
# No. Iterations:                     6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -72.7451     16.063     -4.529      0.000    -104.228     -41.262
# dist             -0.1083      0.003    -33.018      0.000      -0.115      -0.102
# year              0.0392      0.008      4.885      0.000       0.023       0.055
# seasons           0.0128      0.005      2.343      0.019       0.002       0.023
# cold             -0.2196      0.062     -3.533      0.000      -0.341      -0.098
# altitude          0.5253      0.166      3.161      0.002       0.200       0.851
# humid            -0.0290      0.060     -0.482      0.630      -0.147       0.089
# windy            -0.2675      0.060     -4.495      0.000      -0.384      -0.151
# away_game        -0.0523      0.054     -0.961      0.337      -0.159       0.054
# postseason       -0.0821      0.059     -1.388      0.165      -0.198       0.034
# iced             -0.1350      0.082     -1.648      0.099      -0.296       0.026
# turf              0.2746      0.060      4.598      0.000       0.158       0.392
# precipitation    -0.1477      0.093     -1.580      0.114      -0.331       0.035
# pressure         -0.0499      0.116     -0.431      0.667      -0.277       0.177
# =================================================================================

# %%
formula = 'good ~ ' + '+'.join(df_train.drop(['good'], axis=1).columns.values) + '+ cold*windy + postseason*away_game + windy*dist + pressure*iced + seasons*dist'

model = glm_sm(formula, df_train, family=sm.families.Binomial())
result = model.fit(method='irls')
new = Summary(result)
diff, p = new.compare(base, 'inters')
print(f'P(LR|Ho):{p}\n', f'With interactions:{new.log_likelihood}\n', f'Without interactions:{base.log_likelihood}')
# Out:
# P(LR|Ho):0.00011953550181307647
#  With interactions:-4255.3
#  Without interactions:-4262.7

# %%
print(new.result.summary())
# Out:
# Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   good   No. Observations:                10398
# Model:                            GLM   Df Residuals:                    10379
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4255.3
# Date:                Sat, 22 Feb 2020   Deviance:                       8510.6
# Time:                        13:48:24   Pearson chi2:                 9.98e+03
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              -71.6624     16.088     -4.455      0.000    -103.193     -40.131
# dist                    -0.0934      0.006    -14.405      0.000      -0.106      -0.081
# year                     0.0383      0.008      4.767      0.000       0.023       0.054
# seasons                  0.0948      0.029      3.252      0.001       0.038       0.152
# cold                    -0.1395      0.073     -1.908      0.056      -0.283       0.004
# altitude                 0.5293      0.166      3.183      0.001       0.203       0.855
# humid                   -0.0185      0.060     -0.307      0.759      -0.137       0.100
# windy                   -0.0960      0.301     -0.319      0.749      -0.685       0.493
# away_game                0.0136      0.079      0.172      0.863      -0.141       0.168
# postseason              -0.0070      0.081     -0.087      0.931      -0.165       0.151
# iced                    -0.1400      0.089     -1.577      0.115      -0.314       0.034
# turf                     0.2772      0.060      4.639      0.000       0.160       0.394
# precipitation           -0.1492      0.094     -1.596      0.110      -0.333       0.034
# pressure                -0.0551      0.168     -0.328      0.743      -0.385       0.274
# cold:windy              -0.2641      0.122     -2.161      0.031      -0.504      -0.025
# postseason:away_game    -0.1380      0.109     -1.263      0.206      -0.352       0.076
# windy:dist              -0.0020      0.007     -0.291      0.771      -0.016       0.012
# pressure:iced            0.0120      0.232      0.052      0.959      -0.443       0.466
# seasons:dist            -0.0020      0.001     -2.870      0.004      -0.003      -0.001
# ========================================================================================

# %% [markdown]
# We'll use these values in the next study, which is a Bayesian approach to post-2011 data.

# %%
new.summary.to_csv('expanded_results.csv')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Even though we are interested in accurate inference, let's check the model isn't complete garbage.

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
y_t = df_test['good']

# base
y_p = base_result.predict(df_test.drop('good',axis=1))
auc_base = roc_auc_score(y_t, y_p)
curve_base = roc_curve(y_t, y_p)
df_base = pd.DataFrame.from_records(np.column_stack(curve_base), columns=['fpr','tpr','thresholds'])
df_base['type'] = 'base'

# interactions
y_p = result.predict(df_test.drop('good',axis=1))
auc = roc_auc_score(y_t, y_p)
curve = roc_curve(y_t, y_p)
df_int = pd.DataFrame.from_records(np.column_stack(curve), columns=['fpr','tpr','thresholds'])
df_int['type'] = 'interactions'

# dummy - good
y_p = [1]*len(df_test)
y_p = pd.Series(y_p)
auc_dg = roc_auc_score(y_t, y_p)
curve_dg = roc_curve(y_t, y_p)
df_dg = pd.DataFrame.from_records(np.column_stack(curve_dg), columns=['fpr','tpr','thresholds'])
df_dg['type'] = 'All good'

# dummy - random @ P(good)
p = df_train['good'].value_counts(normalize=True)[1]
y_p = pd.Series([1 if p>np.random.rand() else 0 for _ in range(len(df_test))])
auc_dp = roc_auc_score(y_t, y_p)
curve_dp = roc_curve(y_t, y_p)
df_dp = pd.DataFrame.from_records(np.column_stack(curve_dp), columns=['fpr','tpr','thresholds'])
df_dp['type'] = 'P(good)'

# dummy - @ dist>40
y_p = df_test['dist']>40
auc_dd = roc_auc_score(y_t, y_p)
curve_dd = roc_curve(y_t, y_p)
df_dd = pd.DataFrame.from_records(np.column_stack(curve_dd), columns=['fpr','tpr','thresholds'])
df_dd['type'] = '@d>40'

# %%
aucs = pd.Series([auc_dp, auc_dg, auc_base, auc], index=['@p','good','base','with interactions'])
aucs
# Out:
# @p                   0.502605
# good                 0.500000
# base                 0.740937
# with interactions    0.741505
# dtype: float64

# %%
from seaborn import lineplot
df_all = pd.concat([df_base,df_int,df_dg,df_dp,df_dd])
ax = lineplot(x='fpr',y='tpr', data=df_all, hue='type')
ax.set_title('ROC for each model')
# Out:
# Text(0.5, 1.0, 'ROC for each model')

# %% [markdown]
# Interactions and base model have the same predictive power, but I'd argue the interactions provide more accuracte inference. Both are better than the simplest models.

# %% [markdown]
# ### See you in the next notebook.
